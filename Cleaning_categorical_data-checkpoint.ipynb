# %% [markdown]
# **Import the necessary libraries if you are starting a new notebook.**

# %%
import pymysql
from sqlalchemy import create_engine
import pandas as pd
import getpass  # To get the password without showing the input
from sklearn.preprocessing import StandardScaler
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import seaborn as sns
pd.set_option('display.max_columns', None)

# %% [markdown]
# **Load the csv. Use the variable customer_df as customer_df = pd.read_csv().**

# %%
customer_df = pd.read_csv('we_fn_use_c_marketing_customer_value_analysis.csv')

# %%
customer_df.head()
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income Location Code  \
# 0           2/24/11         Employed      F   56274      Suburban
# 1           1/31/11       Unemployed      F       0      Suburban
# 2           2/19/11         Employed      F   48767      Suburban
# 3           1/20/11       Unemployed      M       0      Suburban
# 4            2/3/11         Employed      M   43836         Rural
#
#   Marital Status  Monthly Premium Auto  Months Since Last Claim  \
# 0        Married                    69                       32
# 1         Single                    94                       13
# 2        Married                   108                       18
# 3        Married                   106                       18
# 4         Single                    73                       12
#
#    Months Since Policy Inception  Number of Open Complaints  \
# 0                              5                          0
# 1                             42                          0
# 2                             38                          0
# 3                             65                          0
# 4                             44                          0
#
#    Number of Policies     Policy Type        Policy Renew Offer Type  \
# 0                   1  Corporate Auto  Corporate L3           Offer1
# 1                   8   Personal Auto   Personal L3           Offer3
# 2                   2   Personal Auto   Personal L3           Offer1
# 3                   7  Corporate Auto  Corporate L2           Offer1
# 4                   1   Personal Auto   Personal L1           Offer1
#
#   Sales Channel  Total Claim Amount  Vehicle Class Vehicle Size
# 0         Agent          384.811147   Two-Door Car      Medsize
# 1         Agent         1131.464935  Four-Door Car      Medsize
# 2         Agent          566.472247   Two-Door Car      Medsize
# 3   Call Center          529.881344            SUV      Medsize
# 4         Agent          138.130879  Four-Door Car      Medsize

# %% [markdown]
# **What should we do with the customer_id column?**

# %% [markdown]
# *We have to drop customer_id columnn as it doesn't add value to dataset.*

# %%
customer_df = customer_df.drop(['Customer'], axis = 1)

# %% [markdown]
# **Load the continuous and discrete variables into numericals_df and categorical_df variables**

# %%
numerical_df = customer_df.select_dtypes(np.number)
categorical_df = customer_df.select_dtypes(np.object)
# Out:
# C:\Users\nkhat\AppData\Local\Temp\ipykernel_19320\3412960944.py:2: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   categorical_df = customer_df.select_dtypes(np.object)

# %%
numerical_df
# Out:
#       Customer Lifetime Value  Income  Monthly Premium Auto  \
# 0                 2763.519279   56274                    69
# 1                 6979.535903       0                    94
# 2                12887.431650   48767                   108
# 3                 7645.861827       0                   106
# 4                 2813.692575   43836                    73
# ...                       ...     ...                   ...
# 9129             23405.987980   71941                    73
# 9130              3096.511217   21604                    79
# 9131              8163.890428       0                    85
# 9132              7524.442436   21941                    96
# 9133              2611.836866       0                    77
#
#       Months Since Last Claim  Months Since Policy Inception  \
# 0                          32                              5
# 1                          13                             42
# 2                          18                             38
# 3                          18                             65
# 4                          12                             44
# ...                       ...                            ...
# 9129                       18                             89
# 9130                       14                             28
# 9131                        9                             37
# 9132                       34                              3
# 9133                        3                             90
#
#       Number of Open Complaints  Number of Policies  Total Claim Amount
# 0                             0                   1          384.811147
# 1                             0                   8         1131.464935
# 2                             0                   2          566.472247
# 3                             0                   7          529.881344
# 4                             0                   1          138.130879
# ...                         ...                 ...                 ...
# 9129                          0                   2          198.234764
# 9130                          0                   1          379.200000
# 9131                          3                   2          790.784983
# 9132                          0                   3          691.200000
# 9133                          0                   1          369.600000
#
# [9134 rows x 8 columns]

# %%
categorical_df
# Out:
#            State Response  Coverage Education Effective To Date  \
# 0     Washington       No     Basic  Bachelor           2/24/11
# 1        Arizona       No  Extended  Bachelor           1/31/11
# 2         Nevada       No   Premium  Bachelor           2/19/11
# 3     California       No     Basic  Bachelor           1/20/11
# 4     Washington       No     Basic  Bachelor            2/3/11
# ...          ...      ...       ...       ...               ...
# 9129  California       No     Basic  Bachelor           2/10/11
# 9130  California      Yes  Extended   College           2/12/11
# 9131  California       No  Extended  Bachelor            2/6/11
# 9132  California       No  Extended   College            2/3/11
# 9133  California       No  Extended   College           2/14/11
#
#      EmploymentStatus Gender Location Code Marital Status     Policy Type  \
# 0            Employed      F      Suburban        Married  Corporate Auto
# 1          Unemployed      F      Suburban         Single   Personal Auto
# 2            Employed      F      Suburban        Married   Personal Auto
# 3          Unemployed      M      Suburban        Married  Corporate Auto
# 4            Employed      M         Rural         Single   Personal Auto
# ...               ...    ...           ...            ...             ...
# 9129         Employed      M         Urban        Married   Personal Auto
# 9130         Employed      F      Suburban       Divorced  Corporate Auto
# 9131       Unemployed      M      Suburban         Single  Corporate Auto
# 9132         Employed      M      Suburban        Married   Personal Auto
# 9133       Unemployed      M      Suburban         Single  Corporate Auto
#
#             Policy Renew Offer Type Sales Channel  Vehicle Class Vehicle Size
# 0     Corporate L3           Offer1         Agent   Two-Door Car      Medsize
# 1      Personal L3           Offer3         Agent  Four-Door Car      Medsize
# 2      Personal L3           Offer1         Agent   Two-Door Car      Medsize
# 3     Corporate L2           Offer1   Call Center            SUV      Medsize
# 4      Personal L1           Offer1         Agent  Four-Door Car      Medsize
# ...            ...              ...           ...            ...          ...
# 9129   Personal L1           Offer2           Web  Four-Door Car      Medsize
# 9130  Corporate L3           Offer1        Branch  Four-Door Car      Medsize
# 9131  Corporate L2           Offer1        Branch  Four-Door Car      Medsize
# 9132   Personal L2           Offer3        Branch  Four-Door Car        Large
# 9133  Corporate L3           Offer4   Call Center   Two-Door Car      Medsize
#
# [9134 rows x 15 columns]

# %%
customer_df.shape
# Out:
# (9134, 23)

# %% [markdown]
# **Plot every categorical variable. What can you see in the plots? Note that in the previous lab you used a bar plot to plot categorical data, with each unique category in the column on the x-axis and an appropriate measure on the y-axis. However, this time you will try a different plot. This time in each plot for the categorical variable you will have, each unique category in the column on the x-axis and the target(which is numerical) on the Y-axis**

# %%
#Using boxplot to view categorical columns versus target (numerical)
for i in categorical_df:
    sns.boxplot(data=customer_df, x=i, y='Total Claim Amount', whis = 3)
    plt.show()

# %% [markdown]
# *It can be seen that in many columns, there are many outliers when plotted versus the target column. This means that these columns don't have high correlations with the target.*

# %%
#Using barplot to view categorical columns versus target (numerical)
for i in categorical_df:
    sns.barplot(x=i, y="Total Claim Amount", data=customer_df)
    plt.show()

# %% [markdown]
# *Here it can be seen that the 'marital status' has a more normal distribution compared to the others. In terms of visualization, 'Policy' and 'Effective To Date' don't have an acceptable appearance. Therefore, bucketing can be used to group them*

# %%
customer_df['Policy'].value_counts()
# Out:
# Personal L3     3426
# Personal L2     2122
# Personal L1     1240
# Corporate L3    1014
# Corporate L2     595
# Corporate L1     359
# Special L2       164
# Special L3       148
# Special L1        66
# Name: Policy, dtype: int64

# %% [markdown]
# *It can be grouped into 5 groups. values whose count is less than 1014 can be considered one group.*

# %%
#placing the value_counts of policy in a new dataframe to be able to define a function and group them
vals_policy = pd.DataFrame(customer_df['Policy'].value_counts())

# %%
vals_policy
# Out:
#               Policy
# Personal L3     3426
# Personal L2     2122
# Personal L1     1240
# Corporate L3    1014
# Corporate L2     595
# Corporate L1     359
# Special L2       164
# Special L3       148
# Special L1        66

# %%
vals_policy = vals_policy.reset_index()

# %%
#defining 2 columns for the datafram
vals_policy.columns = ['Policy', 'Count']

# %%
vals_policy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Policy  9 non-null      object
#  1   Count   9 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 272.0+ bytes

# %%
#Grouping the policies less than 1014 into one group
vals_policy_new = vals_policy[vals_policy['Count'] < 1014]

# %%
vals_policy_new
# Out:
#          Policy  Count
# 4  Corporate L2    595
# 5  Corporate L1    359
# 6    Special L2    164
# 7    Special L3    148
# 8    Special L1     66

# %%
#converting the grouped dataframe into a list to define the function
vals_policy_new = list(vals_policy_new['Policy'])

# %%
vals_policy_new
# Out:
# ['Corporate L2', 'Corporate L1', 'Special L2', 'Special L3', 'Special L1']

# %%
#Defining the function
def policy_cleaner(x):
    if x in vals_policy_new:
        return 'other'
    else:
        return x

# %%
#Applying the function
customer_df['Policy'] = customer_df['Policy'].apply(policy_cleaner)

# %%
#Checking if the function works properly
customer_df['Policy'].value_counts()
# Out:
# Personal L3     3426
# Personal L2     2122
# other           1332
# Personal L1     1240
# Corporate L3    1014
# Name: Policy, dtype: int64

# %%
customer_df['Policy'].unique()
# Out:
# array(['Corporate L3', 'Personal L3', 'other', 'Personal L1',
#        'Personal L2'], dtype=object)

# %%
sns.barplot(x='Policy', y="Total Claim Amount", data=customer_df)
plt.show()

# %%
categorical_df['Policy'] = customer_df['Policy']

# %% [markdown]
# *Now the 'Policy' column has a better visualization. The same can be done with 'Effective To Date' column*

# %%
#Checking the values of 'Effective to Date' to decide how to group the data
customer_df['Effective To Date'].value_counts()
# Out:
# 1/10/11    195
# 1/27/11    194
# 2/14/11    186
# 1/26/11    181
# 1/17/11    180
# 1/19/11    179
# 1/31/11    178
# 1/3/11     178
# 1/20/11    173
# 2/26/11    169
# 1/28/11    169
# 2/19/11    168
# 1/5/11     167
# 2/27/11    167
# 1/11/11    166
# 2/4/11     164
# 2/10/11    161
# 2/28/11    161
# 1/2/11     160
# 1/21/11    160
# 1/29/11    160
# 2/22/11    158
# 2/5/11     158
# 2/3/11     158
# 2/7/11     157
# 2/12/11    156
# 1/23/11    155
# 2/1/11     154
# 1/18/11    154
# 1/15/11    153
# 1/14/11    152
# 2/11/11    151
# 1/7/11     151
# 1/25/11    151
# 2/25/11    149
# 1/8/11     149
# 2/18/11    149
# 2/2/11     149
# 1/1/11     148
# 2/21/11    148
# 1/24/11    147
# 1/9/11     146
# 1/30/11    145
# 1/13/11    145
# 2/6/11     144
# 1/6/11     143
# 2/23/11    143
# 1/16/11    142
# 2/16/11    139
# 2/13/11    139
# 2/24/11    139
# 2/9/11     137
# 2/17/11    136
# 1/22/11    136
# 2/8/11     134
# 2/20/11    132
# 2/15/11    130
# 1/12/11    126
# 1/4/11     115
# Name: Effective To Date, dtype: int64

# %% [markdown]
# *The values are between Jan and Feb. So the data can be divided into 2 groups of only Jan and Feb*

# %%
#changing the format of the column to datetime
vals_effective = pd.to_datetime(customer_df['Effective To Date'])

# %%
#defining a function to divide the data into two groups of Jan or Feb
def date_divider(x):
        if x.month == 1:
            return 'Jan'
        else:
            return 'Feb'

# %%
#applying the function to dataframe
vals_effective = vals_effective.apply(date_divider)

# %%
#putting the data in the format of a dataframe
vals_effective = pd.DataFrame(vals_effective)

# %%
vals_effective
# Out:
#      Effective To Date
# 0                  Feb
# 1                  Jan
# 2                  Feb
# 3                  Jan
# 4                  Feb
# ...                ...
# 9129               Feb
# 9130               Feb
# 9131               Feb
# 9132               Feb
# 9133               Feb
#
# [9134 rows x 1 columns]

# %%
vals_effective.value_counts()
# Out:
# Effective To Date
# Jan                  4898
# Feb                  4236
# dtype: int64

# %%
#Assining the divided groups into the 'Effective To Date' column
customer_df['Effective To Date'] = vals_effective

# %%
customer_df
# Out:
#            State  Customer Lifetime Value Response  Coverage Education  \
# 0     Washington              2763.519279       No     Basic  Bachelor
# 1        Arizona              6979.535903       No  Extended  Bachelor
# 2         Nevada             12887.431650       No   Premium  Bachelor
# 3     California              7645.861827       No     Basic  Bachelor
# 4     Washington              2813.692575       No     Basic  Bachelor
# ...          ...                      ...      ...       ...       ...
# 9129  California             23405.987980       No     Basic  Bachelor
# 9130  California              3096.511217      Yes  Extended   College
# 9131  California              8163.890428       No  Extended  Bachelor
# 9132  California              7524.442436       No  Extended   College
# 9133  California              2611.836866       No  Extended   College
#
#      Effective To Date EmploymentStatus Gender  Income Location Code  \
# 0                  Feb         Employed      F   56274      Suburban
# 1                  Jan       Unemployed      F       0      Suburban
# 2                  Feb         Employed      F   48767      Suburban
# 3                  Jan       Unemployed      M       0      Suburban
# 4                  Feb         Employed      M   43836         Rural
# ...                ...              ...    ...     ...           ...
# 9129               Feb         Employed      M   71941         Urban
# 9130               Feb         Employed      F   21604      Suburban
# 9131               Feb       Unemployed      M       0      Suburban
# 9132               Feb         Employed      M   21941      Suburban
# 9133               Feb       Unemployed      M       0      Suburban
#
#      Marital Status  Monthly Premium Auto  Months Since Last Claim  \
# 0           Married                    69                       32
# 1            Single                    94                       13
# 2           Married                   108                       18
# 3           Married                   106                       18
# 4            Single                    73                       12
# ...             ...                   ...                      ...
# 9129        Married                    73                       18
# 9130       Divorced                    79                       14
# 9131         Single                    85                        9
# 9132        Married                    96                       34
# 9133         Single                    77                        3
#
#       Months Since Policy Inception  Number of Open Complaints  \
# 0                                 5                          0
# 1                                42                          0
# 2                                38                          0
# 3                                65                          0
# 4                                44                          0
# ...                             ...                        ...
# 9129                             89                          0
# 9130                             28                          0
# 9131                             37                          3
# 9132                              3                          0
# 9133                             90                          0
#
#       Number of Policies     Policy Type        Policy Renew Offer Type  \
# 0                      1  Corporate Auto  Corporate L3           Offer1
# 1                      8   Personal Auto   Personal L3           Offer3
# 2                      2   Personal Auto   Personal L3           Offer1
# 3                      7  Corporate Auto         other           Offer1
# 4                      1   Personal Auto   Personal L1           Offer1
# ...                  ...             ...           ...              ...
# 9129                   2   Personal Auto   Personal L1           Offer2
# 9130                   1  Corporate Auto  Corporate L3           Offer1
# 9131                   2  Corporate Auto         other           Offer1
# 9132                   3   Personal Auto   Personal L2           Offer3
# 9133                   1  Corporate Auto  Corporate L3           Offer4
#
#      Sales Channel  Total Claim Amount  Vehicle Class Vehicle Size
# 0            Agent          384.811147   Two-Door Car      Medsize
# 1            Agent         1131.464935  Four-Door Car      Medsize
# 2            Agent          566.472247   Two-Door Car      Medsize
# 3      Call Center          529.881344            SUV      Medsize
# 4            Agent          138.130879  Four-Door Car      Medsize
# ...            ...                 ...            ...          ...
# 9129           Web          198.234764  Four-Door Car      Medsize
# 9130        Branch          379.200000  Four-Door Car      Medsize
# 9131        Branch          790.784983  Four-Door Car      Medsize
# 9132        Branch          691.200000  Four-Door Car        Large
# 9133   Call Center          369.600000   Two-Door Car      Medsize
#
# [9134 rows x 23 columns]

# %%
categorical_df['Effective To Date'] = customer_df['Effective To Date']

# %%
#Checkin if the visualization has improved
sns.barplot(x='Effective To Date', y="Total Claim Amount", data=customer_df)
plt.show()

# %% [markdown]
# *It can be seen that the column visualization has improved after grouping the data only into two groups compared to the previous plot.*

# %% [markdown]
# *Checking the values of Vehicle Class', this column also can be dealt with bucketing method as there are values with less frequency.*

# %%
categorical_df['Vehicle Class'].value_counts()
# Out:
# Four-Door Car    4621
# Two-Door Car     1886
# SUV              1796
# Sports Car        484
# Luxury SUV        184
# Luxury Car        163
# Name: Vehicle Class, dtype: int64

# %%
vals_size = pd.DataFrame(customer_df['Vehicle Class'].value_counts())

# %%
vals_size
# Out:
#                Vehicle Class
# Four-Door Car           4621
# Two-Door Car            1886
# SUV                     1796
# Sports Car               484
# Luxury SUV               184
# Luxury Car               163

# %%
vals_size = vals_size.reset_index()

# %%
vals_size.columns = ['Vehicle Class', 'Count']

# %%
vals_size_new = vals_size[vals_size['Count'] < 1796]

# %%
vals_size_new = list(vals_size_new['Vehicle Class'])

# %%
def size_cleaner(x):
    if x in vals_size_new:
        return 'other'
    else:
        return x

# %%
customer_df['Vehicle Class'] = customer_df['Vehicle Class'].apply(size_cleaner)

# %%
customer_df['Vehicle Class'].value_counts()
# Out:
# Four-Door Car    4621
# Two-Door Car     1886
# SUV              1796
# other             831
# Name: Vehicle Class, dtype: int64

# %%
categorical_df['Vehicle Class'] = customer_df['Vehicle Class']

# %% [markdown]
# **For the categorical data, check if there is any data cleaning that need to perform. Hint: You can use the function value_counts() on each of the categorical columns and check the representation of different categories in each column. Discuss if this information might in some way be used for data cleaning.**

# %%
categorical_df
# Out:
#            State Response  Coverage Education Effective To Date  \
# 0     Washington       No     Basic  Bachelor               Feb
# 1        Arizona       No  Extended  Bachelor               Jan
# 2         Nevada       No   Premium  Bachelor               Feb
# 3     California       No     Basic  Bachelor               Jan
# 4     Washington       No     Basic  Bachelor               Feb
# ...          ...      ...       ...       ...               ...
# 9129  California       No     Basic  Bachelor               Feb
# 9130  California      Yes  Extended   College               Feb
# 9131  California       No  Extended  Bachelor               Feb
# 9132  California       No  Extended   College               Feb
# 9133  California       No  Extended   College               Feb
#
#      EmploymentStatus Gender Location Code Marital Status     Policy Type  \
# 0            Employed      F      Suburban        Married  Corporate Auto
# 1          Unemployed      F      Suburban         Single   Personal Auto
# 2            Employed      F      Suburban        Married   Personal Auto
# 3          Unemployed      M      Suburban        Married  Corporate Auto
# 4            Employed      M         Rural         Single   Personal Auto
# ...               ...    ...           ...            ...             ...
# 9129         Employed      M         Urban        Married   Personal Auto
# 9130         Employed      F      Suburban       Divorced  Corporate Auto
# 9131       Unemployed      M      Suburban         Single  Corporate Auto
# 9132         Employed      M      Suburban        Married   Personal Auto
# 9133       Unemployed      M      Suburban         Single  Corporate Auto
#
#             Policy Renew Offer Type Sales Channel  Vehicle Class Vehicle Size
# 0     Corporate L3           Offer1         Agent   Two-Door Car      Medsize
# 1      Personal L3           Offer3         Agent  Four-Door Car      Medsize
# 2      Personal L3           Offer1         Agent   Two-Door Car      Medsize
# 3            other           Offer1   Call Center            SUV      Medsize
# 4      Personal L1           Offer1         Agent  Four-Door Car      Medsize
# ...            ...              ...           ...            ...          ...
# 9129   Personal L1           Offer2           Web  Four-Door Car      Medsize
# 9130  Corporate L3           Offer1        Branch  Four-Door Car      Medsize
# 9131         other           Offer1        Branch  Four-Door Car      Medsize
# 9132   Personal L2           Offer3        Branch  Four-Door Car        Large
# 9133  Corporate L3           Offer4   Call Center   Two-Door Car      Medsize
#
# [9134 rows x 15 columns]

# %%
categorical_df['State'].value_counts()
# Out:
# California    3150
# Oregon        2601
# Arizona       1703
# Nevada         882
# Washington     798
# Name: State, dtype: int64

# %%
categorical_df.isna().sum()
# Out:
# State                0
# Response             0
# Coverage             0
# Education            0
# Effective To Date    0
# EmploymentStatus     0
# Gender               0
# Location Code        0
# Marital Status       0
# Policy Type          0
# Policy               0
# Renew Offer Type     0
# Sales Channel        0
# Vehicle Class        0
# Vehicle Size         0
# dtype: int64

# %% [markdown]
# *After doing the value_counts() and checking for the null values, there are no columns with null values that need to be dropped or fixed.*

# %%
#Checking the outliers after bucketing some columns:
for i in categorical_df:
    sns.boxplot(data=customer_df, x=i, y='Total Claim Amount', whis = 5)
    plt.show()

# %% [markdown]
# **Summary: After checking the boxplot and bars for categorical data, it can be seen that there are some outliers in categorical columns. However, there isn't a process to deal with outliers of categorical columns as they aren't numerica values. One way, as it has been done before can be using value_counts() and bucketing the least frequent values in another group in order to have a more balanced data and less outliers when compared to the target.**
